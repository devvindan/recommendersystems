# %% [markdown]
# # Eval Assignment Example Analysis
#
# This notebook shows how to produce the graphs in the assignment instructions.

# %% [markdown]
# ## Setup
#
# First, we need to import some Python packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing Data
#
# Then we import the data.

# %%
df = pd.read_csv('build/eval-results.csv')
df = df.rename(columns=lambda x: x.replace('.', '_'))
df
# Out:
#     Partition   Algorithm  BuildTime  TestTime  NUsers  NAttempted  NGood  \
# 0           1  GlobalMean      0.216     1.178   173.0       865.0  865.0
# 1           5     Popular      0.147     0.589     NaN         NaN    NaN
# 2           1     Popular      0.220     0.629     NaN         NaN    NaN
# 3           5  GlobalMean      0.088     0.072   172.0       860.0  860.0
# 4           5    ItemMean      0.093     0.869   172.0       860.0  860.0
# 5           1    ItemMean      0.060     0.478   173.0       865.0  865.0
# 6           5    PersMean      1.004     0.360   172.0       860.0  860.0
# 7           1    PersMean      0.377     0.234   173.0       865.0  865.0
# 8           4    ItemMean      0.077     0.275   172.0       860.0  860.0
# 9           4     Popular      0.085     0.309     NaN         NaN    NaN
# 10          4  GlobalMean      0.134     0.014   172.0       860.0  860.0
# 11          4    PersMean      0.264     0.385   172.0       860.0  860.0
# 12          2  GlobalMean      0.016     0.014   173.0       865.0  865.0
# 13          2     Popular      0.040     0.110     NaN         NaN    NaN
# 14          2    ItemMean      0.009     0.306   173.0       865.0  865.0
# 15          2    PersMean      0.148     0.334   173.0       865.0  865.0
# 16          3  GlobalMean      0.023     0.020   172.0       860.0  860.0
# 17          3     Popular      0.050     0.232     NaN         NaN    NaN
# 18          3    ItemMean      0.033     0.253   172.0       860.0  860.0
# 19          3    PersMean      0.151     0.170   172.0       860.0  860.0
#
#     Coverage  RMSE_ByUser  RMSE_ByRating  Predict_nDCG  TopN_ActualLength  \
# 0        1.0     0.913773       0.971289      0.942881                NaN
# 1        NaN          NaN            NaN           NaN               10.0
# 2        NaN          NaN            NaN           NaN               10.0
# 3        1.0     0.949340       1.022592      0.939204                NaN
# 4        1.0     0.865944       0.945420      0.960667               10.0
# 5        1.0     0.846742       0.918749      0.962223               10.0
# 6        1.0     0.796419       0.873847      0.960667               10.0
# 7        1.0     0.740479       0.825009      0.962223               10.0
# 8        1.0     0.805856       0.877792      0.967275               10.0
# 9        NaN          NaN            NaN           NaN               10.0
# 10       1.0     0.914807       0.980373      0.939124                NaN
# 11       1.0     0.715982       0.788661      0.967275               10.0
# 12       1.0     0.971937       1.049804      0.938129                NaN
# 13       NaN          NaN            NaN           NaN               10.0
# 14       1.0     0.876684       0.971898      0.964324               10.0
# 15       1.0     0.770310       0.867928      0.964324               10.0
# 16       1.0     0.932252       0.996081      0.942986                NaN
# 17       NaN          NaN            NaN           NaN               10.0
# 18       1.0     0.824526       0.890884      0.969554               10.0
# 19       1.0     0.715446       0.793470      0.969554               10.0
#
#     TopN_nDCG       MRR       MAP  TopN_TagEntropy
# 0         NaN       NaN       NaN              NaN
# 1    0.083382  0.146092  0.142745              NaN
# 2    0.081752  0.178649  0.171775              NaN
# 3         NaN       NaN       NaN              NaN
# 4    0.045492  0.087798  0.089821              NaN
# 5    0.023417  0.054789  0.046832              NaN
# 6    0.042190  0.091189  0.085617              NaN
# 7    0.025640  0.053280  0.051457              NaN
# 8    0.024095  0.035412  0.037518              NaN
# 9    0.104689  0.222776  0.213134              NaN
# 10        NaN       NaN       NaN              NaN
# 11   0.024095  0.036679  0.036896              NaN
# 12        NaN       NaN       NaN              NaN
# 13   0.087397  0.172504  0.169214              NaN
# 14   0.019947  0.041729  0.041729              NaN
# 15   0.019947  0.041729  0.041729              NaN
# 16        NaN       NaN       NaN              NaN
# 17   0.075831  0.130094  0.117444              NaN
# 18   0.017776  0.035793  0.031077              NaN
# 19   0.015421  0.027136  0.024746              NaN

# %% [markdown]
# ## Example Plots
#
# Now we can produce the basic plots.
#
# First, we want to only deal with the baseline algorithms right now.

# %%
baselines = df[df.NNbrs.isnull()]
baselines

# %% [markdown]
# Then we can plot RMSE:

# %%
const_rmse = baselines.pivot(index='Partition', columns='Algorithm', values='RMSE_ByUser')
const_rmse.plot(kind='box')

# %% [markdown]
# Now we can do top-N nDCG:

# %%
baselines.pivot(index='Partition', columns='Algorithm', values='TopN_nDCG').plot(kind='box')

# %% [markdown]
# And Predict nDCG:

# %%
baselines.pivot(index='Partition', columns='Algorithm', values='Predict_nDCG').plot(kind='box')
